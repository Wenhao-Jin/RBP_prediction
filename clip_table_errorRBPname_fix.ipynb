# %%
import pandas as pd
import numpy as np
import re

# %%
public_clip_table=pd.read_csv('public_clip_distributions.csv')
public_clip_table2=pd.read_csv('public_clip_distributions.csv')
public_clip_table.index=np.array(public_clip_table.loc[:,public_clip_table.columns[0]])
public_clip_table=public_clip_table.drop(public_clip_table.columns[0],axis=1)
public_clip_table2.index=np.array(public_clip_table2.loc[:,public_clip_table2.columns[0]])
public_clip_table2=public_clip_table2.drop(public_clip_table2.columns[0],axis=1)

# %%
public_clip_table
# Out:
#                   293T_hnRNPA1_WT_rep1  293T_hnRNPF_WT_rep1  \
# all                                940                 1199
# cds                                120                  203
# distintron500                      357                  738
# five_prime_utrs                      0                    0
# proxintron500                      346                  258
# three_prime_utrs                   117                    0
# uncatagorized                      982                 1620
#
#                   293T_hnRNPM_WT_rep1  293T_hnRNPU_WT_rep1  \
# all                              3117                 4244
# cds                                 0                 1731
# distintron500                    2178                 1358
# five_prime_utrs                   368                  112
# proxintron500                     571                  924
# three_prime_utrs                    0                  119
# uncatagorized                    6418                 5736
#
#                   C2C12_Cstf64_WT_rep1  ERR018282  ERR018283  \
# all                              10550        331        161
# cds                               2178          0          0
# distintron500                     2847         41          0
# five_prime_utrs                     85          0          0
# proxintron500                      983        176         80
# three_prime_utrs                  4457        114         81
# uncatagorized                     2056        481        383
#
#                   HEK293FlpIn_FMR1-iso1_WT_rep1  \
# all                                      110604
# cds                                       55986
# distintron500                              4190
# five_prime_utrs                            1293
# proxintron500                              3717
# three_prime_utrs                          45418
# uncatagorized                              3228
#
#                   HEK293FlpIn_FMR1-iso7_WT_rep1  HEK293_Ago2_WT_rep1  \
# all                                           0                  181
# cds                                       23566                    0
# distintron500                              1361                  181
# five_prime_utrs                            2051                    0
# proxintron500                              1129                    0
# three_prime_utrs                           5061                    0
# uncatagorized                                 0                   28
#
#                          ...           SRR765758  SRR765759  SRR765760  \
# all                      ...               34230       1376      61230
# cds                      ...               29166        636      54952
# distintron500            ...                 607        278        645
# five_prime_utrs          ...                1253         81       1450
# proxintron500            ...                2195        381       2893
# three_prime_utrs         ...                1009          0       1290
# uncatagorized            ...                2608       1107       2276
#
#                   SRR765761  SRR949130  WholeBrain_Mbnl_WT_rep1  \
# all                    3711        925                    22771
# cds                    2539        248                      419
# distintron500           335        449                     1004
# five_prime_utrs         253         22                      132
# proxintron500           537        171                      287
# three_prime_utrs         47         35                    20929
# uncatagorized          1147        306                      819
#
#                   WholeBrain_fustls_rep1  mESC_Ago2_WT_rep1  \
# all                               211879               1175
# cds                                49024                 16
# distintron500                      21803                798
# five_prime_utrs                     5222                  0
# proxintron500                      69349                361
# three_prime_utrs                   66481                  0
# uncatagorized                       8880                454
#
#                   mESC_Ago2_dicerNull_rep1  mESC_LIN28A_WT_rep1
# all                                      0               263730
# cds                                    134               169837
# distintron500                         1502                 3433
# five_prime_utrs                         98                 2181
# proxintron500                          810                 2570
# three_prime_utrs                        22                85709
# uncatagorized                            0                 6608
#
# [7 rows x 224 columns]

# %%
index_table=pd.read_table('Public CLIP _Database_ - Sheet1.tsv')
index_table2=index_table[['SRA','replicate','gencode_v17_id','Species','hg19_equivalent_gencode','Modification']]

# %%
#correct the items with SRR* to sample name
columns=[]
p=re.compile("^SRR.*")
for i in range(0, len(public_clip_table.columns)):
    if(p.search(public_clip_table.columns[i])):
        tmp=index_table2.ix[:,'replicate'][index_table2['SRA']==public_clip_table.columns[i]].get_values()
        if(tmp):
            columns.append((index_table2.ix[:,'replicate'][index_table2['SRA']==public_clip_table.columns[i]].get_values())[0])
        else:
            columns.append(np.nan)
#        columns.append((index_table2.ix[:,'replicate'][index_table2['SRA']==public_clip_table.columns[i]].get_values())[0])
    else:
        columns.append(public_clip_table.columns[i])
len(columns)
public_clip_table.columns=columns
public_clip_table
# Out:
#                   293T_hnRNPA1_WT_rep1  293T_hnRNPF_WT_rep1  \
# all                                940                 1199
# cds                                120                  203
# distintron500                      357                  738
# five_prime_utrs                      0                    0
# proxintron500                      346                  258
# three_prime_utrs                   117                    0
# uncatagorized                      982                 1620
#
#                   293T_hnRNPM_WT_rep1  293T_hnRNPU_WT_rep1  \
# all                              3117                 4244
# cds                                 0                 1731
# distintron500                    2178                 1358
# five_prime_utrs                   368                  112
# proxintron500                     571                  924
# three_prime_utrs                    0                  119
# uncatagorized                    6418                 5736
#
#                   C2C12_Cstf64_WT_rep1  ERR018282  ERR018283  \
# all                              10550        331        161
# cds                               2178          0          0
# distintron500                     2847         41          0
# five_prime_utrs                     85          0          0
# proxintron500                      983        176         80
# three_prime_utrs                  4457        114         81
# uncatagorized                     2056        481        383
#
#                   HEK293FlpIn_FMR1-iso1_WT_rep1  \
# all                                      110604
# cds                                       55986
# distintron500                              4190
# five_prime_utrs                            1293
# proxintron500                              3717
# three_prime_utrs                          45418
# uncatagorized                              3228
#
#                   HEK293FlpIn_FMR1-iso7_WT_rep1  HEK293_Ago2_WT_rep1  \
# all                                           0                  181
# cds                                       23566                    0
# distintron500                              1361                  181
# five_prime_utrs                            2051                    0
# proxintron500                              1129                    0
# three_prime_utrs                           5061                    0
# uncatagorized                                 0                   28
#
#                          ...           MEF_SRSF1_WT_rep1  MEF_SRSF1_WT_rep1  \
# all                      ...                       34230               1376
# cds                      ...                       29166                636
# distintron500            ...                         607                278
# five_prime_utrs          ...                        1253                 81
# proxintron500            ...                        2195                381
# three_prime_utrs         ...                        1009                  0
# uncatagorized            ...                        2608               1107
#
#                   MEF_SRSF1_siSRSF2_rep1  MEF_SRSF1_siSRSF2_rep1  NaN  \
# all                                61230                    3711  925
# cds                                54952                    2539  248
# distintron500                        645                     335  449
# five_prime_utrs                     1450                     253   22
# proxintron500                       2893                     537  171
# three_prime_utrs                    1290                      47   35
# uncatagorized                       2276                    1147  306
#
#                   WholeBrain_Mbnl_WT_rep1  WholeBrain_fustls_rep1  \
# all                                 22771                  211879
# cds                                   419                   49024
# distintron500                        1004                   21803
# five_prime_utrs                       132                    5222
# proxintron500                         287                   69349
# three_prime_utrs                    20929                   66481
# uncatagorized                         819                    8880
#
#                   mESC_Ago2_WT_rep1  mESC_Ago2_dicerNull_rep1  \
# all                            1175                         0
# cds                              16                       134
# distintron500                   798                      1502
# five_prime_utrs                   0                        98
# proxintron500                   361                       810
# three_prime_utrs                  0                        22
# uncatagorized                   454                         0
#
#                   mESC_LIN28A_WT_rep1
# all                            263730
# cds                            169837
# distintron500                    3433
# five_prime_utrs                  2181
# proxintron500                    2570
# three_prime_utrs                85709
# uncatagorized                    6608
#
# [7 rows x 224 columns]

# %%
#find ensembl id for each sample
ens_columns=[]
for sample in public_clip_table2.columns:
    tmp = index_table2['gencode_v17_id'][index_table2['replicate']==sample].get_values()
    if(len(tmp)):
        ens_columns.append(np.array(tmp)[0])
    else:
        tmp2=index_table2['gencode_v17_id'][index_table2['SRA']==sample].get_values()
        if(len(tmp2)):
            ens_columns.append(np.array(tmp2)[0])
        else:
            print sample
            ens_columns.append(np.nan)
ens_hg19_columns=[]
for sample in public_clip_table2.columns:
    tmp3 = index_table2['hg19_equivalent_gencode'][index_table2['replicate']==sample].get_values()
    if(len(tmp3)):
        ens_hg19_columns.append(np.array(tmp3)[0])
    else:
        tmp4=index_table2['hg19_equivalent_gencode'][index_table2['SRA']==sample].get_values()
        if(len(tmp4)):
            ens_hg19_columns.append(np.array(tmp4)[0])
        else:
            print sample
            ens_hg19_columns.append(np.nan)
Modification_columns=[]
for sample in public_clip_table2.columns:
    tmp5 = index_table2['Modification'][index_table2['replicate']==sample].get_values()
    if(len(tmp5)):
        Modification_columns.append(np.array(tmp5)[0])
    else:
        tmp6=index_table2['Modification'][index_table2['SRA']==sample].get_values()
        if(len(tmp6)):
            Modification_columns.append(np.array(tmp6)[0])
        else:
            print sample
            Modification_columns.append(np.nan)
len(Modification_columns)
# Out:
# HEK293_UPF1_WT_rep1
# SRR606193
# WholeBrain_fustls_rep1
# HEK293_UPF1_WT_rep1
# SRR606193
# WholeBrain_fustls_rep1
# HEK293_UPF1_WT_rep1
# SRR606193
# WholeBrain_fustls_rep1
# 224

# %%
public_clip_table3=public_clip_table2.transpose()
#public_clip_table2.loc['ensembl_id']=ens_columns
#public_clip_table2.loc['ens_hg19_id']=ens_hg19_columns
public_clip_table3['ensembl_id']=ens_columns
public_clip_table3['ensembl_hg19_id']=ens_hg19_columns
public_clip_table3['Modification']=Modification_columns
public_clip_table3.to_csv('public_clip_distribution_revised2.csv')
